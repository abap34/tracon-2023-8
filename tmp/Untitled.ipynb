# %%
import pandas as pd

# %%
pd.read_csv('atmaCup15_dataset/anime.csv')
# Out:
#                   anime_id                                             genres  \
# 0     000ba7f7e34e107e7544       Comedy, Sci-Fi, Seinen, Slice of Life, Space
# 1     00427279d72064e7fb69  Adventure, Slice of Life, Mystery, Historical,...
# 2     00444b67aaabdf740a68  Adventure, Slice of Life, Mystery, Historical,...
# 3     00839a3507ab168abe75                     Comedy, Ecchi, Fantasy, School
# 4     0192331235e110fe4f76     Comedy, Harem, Romance, Sci-Fi, Shounen, Space
# ...                    ...                                                ...
# 1995  ff73475b68001c5e533d  Adventure, Romance, Mecha, Military, Sci-Fi, H...
# 1996  ff8611bae4e43862381f                             Ecchi, Romance, School
# 1997  ffa143ffd4abec9d2707                  Action, Fantasy, Military, Sci-Fi
# 1998  ffb4819df40db39facfa         Action, Adventure, Fantasy, School, Sci-Fi
# 1999  ffc3cf0c5f60dd844611  Action, Mecha, Romance, Super Power, Supernatu...
#
# ...

# %%
pd.read_csv('atmaCup15_dataset/test.csv')
# Out:
#                      user_id              anime_id
# 0       0008e10fb39e55447333  04068820a73e52dc3b32
# 1       0008e10fb39e55447333  04a3d0b122b24965e909
# 2       0008e10fb39e55447333  1447fe1f10b59912d6a8
# 3       0008e10fb39e55447333  2622632598c68682afd5
# 4       0008e10fb39e55447333  2701850c7216516fec46
# ...                      ...                   ...
# 117671  ffe85a36cd20500faa58  f508b02efeac8ecb8cc0
# 117672  ffe85a36cd20500faa58  f5b8ecea3beea4b82d79
# 117673  ffe85a36cd20500faa58  f6c208226b6b69948053
# 117674  ffe85a36cd20500faa58  fe67592c312fc1e17745
# 117675  ffe85a36cd20500faa58  ff73475b68001c5e533d
#
# [117676 rows x 2 columns]

# %%
pd.read_csv('atmaCup15_dataset/train.csv')
# Out:
#                      user_id              anime_id  score
# 0       0008e10fb39e55447333  0669cc0219d468761195      2
# 1       0008e10fb39e55447333  111adb8835b8a1a2cf54     10
# 2       0008e10fb39e55447333  1fc8683c393432a2f9c7      1
# 3       0008e10fb39e55447333  2290175205d55e81b197      8
# 4       0008e10fb39e55447333  28f173b60331d5cabb0d      9
# ...                      ...                   ...    ...
# 136396  ffa6ff8006f8630f3d11  e9ba5ca32ea7e22e0a55      6
# 136397  ffa6ff8006f8630f3d11  ea2be994d7e36d2a720a      7
# 136398  ffa6ff8006f8630f3d11  ee3804a55e2b4ad58aad      7
# 136399  ffa6ff8006f8630f3d11  fc143f3fa9979ab1c230      9
# 136400  ffa6ff8006f8630f3d11  fe1ca9ed790a7d359713      7
#
# [136401 rows x 3 columns]
